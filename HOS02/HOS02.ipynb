# %%
print("hello")
# Out:
# hello

# %%
greetings = "Hello from CS11A inside Jupyter Notebook"
print(greetings)
# Out:
# Hello from CS11A inside Jupyter Notebook

# %%
from IPython.display import Markdown, display

md = """# What is Copilot and how does it work?

**GitHub Copilot** is an AI-powered coding assistant that provides real-time code suggestions and completions inside code editors. It helps write functions, boilerplate, and small algorithms by predicting likely code based on the current context.

## How it works
- It uses large language models trained on a mixture of public source code, natural language, and other permissively licensed data to learn coding patterns.
- When you type, Copilot considers the file content, nearby code, and comments to generate suggestions (single-line completions or multi-line code blocks).
- Suggestions are ranked and presented to the user; you can accept, edit, or discard them.
- It runs inference in the cloud (or via a hosted service), sending limited context from your editor to the model and returning candidate completions.
- Best used as an assistant: it speeds up development but requires human review for correctness, style, licensing, and security.

## Notes
- Copilot helps productivity but is not a substitute for testing, code review, and understanding the generated code.
- Be mindful of licensing and sensitive data when accepting suggested code.
"""

display(Markdown(md))
# Out:
# # What is Copilot and how does it work?
#
# **GitHub Copilot** is an AI-powered coding assistant that provides real-time code suggestions and completions inside code editors. It helps write functions, boilerplate, and small algorithms by predicting likely code based on the current context.
#
# ## How it works
# - It uses large language models trained on a mixture of public source code, natural language, and other permissively licensed data to learn coding patterns.
# - When you type, Copilot considers the file content, nearby code, and comments to generate suggestions (single-line completions or multi-line code blocks).
# - Suggestions are ranked and presented to the user; you can accept, edit, or discard them.
# - It runs inference in the cloud (or via a hosted service), sending limited context from your editor to the model and returning candidate completions.
# ...
